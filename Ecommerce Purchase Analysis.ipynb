# %%
import pandas as pd
import numpy as np

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Admin'

# %%
df = pd.read_csv("E:\Data Science With Python - Sakshi\Sakshi's Google drive folder\Sakshi - October Python weekend batch\Ecommerce Purchases")

# %%
df
# Out:
#                                                 Address    Lot AM or PM  \
# 0     16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1     9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                      Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3                 7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4     23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
# ...                                                 ...    ...      ...
# 9995      966 Castaneda Locks\nWest Juliafurt, CO 96415  92 XI       PM
# 9996  832 Curtis Dam Suite 785\nNorth Edwardburgh, T...  41 JY       AM
# 9997              Unit 4434 Box 6343\nDPO AE 28026-0283  74 Zh       AM
# 9998               0096 English Rest\nRoystad, IA 12457  74 cL       PM
# 9999     40674 Barrett Stravenue\nGrimesville, WI 79682  64 Hr       AM
#
#                                            Browser Info  \
# ...

# %%
df.head()
# Out:
#                                              Address    Lot AM or PM  \
# 0  16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1  9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                   Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3              7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4  23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
#
#                                         Browser Info  \
# 0  Opera/9.56.(X11; Linux x86_64; sl-SI) Presto/2...
# 1  Opera/8.93.(Windows 98; Win 9x 4.90; en-US) Pr...
# 2  Mozilla/5.0 (compatible; MSIE 9.0; Windows NT ...
# 3  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_8_0 ...
# 4  Opera/9.58.(X11; Linux x86_64; it-IT) Presto/2...
#
#                            Company       Credit Card CC Exp Date  \
# 0                  Martinez-Herman  6011929061123406       02/20
# 1  Fletcher, Richards and Whitaker  3337758169645356       11/18
# ...

# %% [markdown]
# Question No1 - Check the how many rows and column are there in data set

# %%
#Answer- 

df.shape
# Out:
# (10000, 14)

# %% [markdown]
# Question No2 - Is there Nan value in the data?

# %%
#Answer-


df.isna().sum()     #so there is no NaN value
# Out:
# Address             0
# Lot                 0
# AM or PM            0
# Browser Info        0
# Company             0
# Credit Card         0
# CC Exp Date         0
# CC Security Code    0
# CC Provider         0
# Email               0
# Job                 0
# IP Address          0
# Language            0
# Purchase Price      0
# dtype: int64

# %% [markdown]
# Question No 3 -- What is the average purchase price

# %%
#Answer-

df["Purchase Price"].mean()
# Out:
# 50.34730200000025

# %%
#Or-

df.describe()
# Out:
#         Credit Card  CC Security Code  Purchase Price
# count  1.000000e+04      10000.000000    10000.000000
# mean   2.341374e+15        907.217800       50.347302
# std    2.256103e+15       1589.693035       29.015836
# min    6.040186e+10          0.000000        0.000000
# 25%    3.056322e+13        280.000000       25.150000
# 50%    8.699942e+14        548.000000       50.505000
# 75%    4.492298e+15        816.000000       75.770000
# max    6.012000e+15       9993.000000       99.990000

# %% [markdown]
# Question 4 - What were the highest and lowest Purchase Price?

# %%
#Answer-

df.describe()
# Out:
#         Credit Card  CC Security Code  Purchase Price
# count  1.000000e+04      10000.000000    10000.000000
# mean   2.341374e+15        907.217800       50.347302
# std    2.256103e+15       1589.693035       29.015836
# min    6.040186e+10          0.000000        0.000000
# 25%    3.056322e+13        280.000000       25.150000
# 50%    8.699942e+14        548.000000       50.505000
# 75%    4.492298e+15        816.000000       75.770000
# max    6.012000e+15       9993.000000       99.990000

# %%
#or
df["Purchase Price"].max()
# Out:
# 99.99

# %%
#or
df["Purchase Price"].min()
# Out:
# 0.0

# %% [markdown]
# Question No 5 - How many people have their english is choice as langauge for website?

# %%
#Answer-

df[df["Language"]== "en"].count()
# Out:
# Address             1098
# Lot                 1098
# AM or PM            1098
# Browser Info        1098
# Company             1098
# Credit Card         1098
# CC Exp Date         1098
# CC Security Code    1098
# CC Provider         1098
# Email               1098
# Job                 1098
# IP Address          1098
# Language            1098
# Purchase Price      1098
# dtype: int64

# %%
#or.

df.groupby("Language").count()
# Out:
#           Address   Lot  AM or PM  Browser Info  Company  Credit Card  \
# Language
# de           1155  1155      1155          1155     1155         1155
# el           1137  1137      1137          1137     1137         1137
# en           1098  1098      1098          1098     1098         1098
# es           1095  1095      1095          1095     1095         1095
# fr           1097  1097      1097          1097     1097         1097
# it           1086  1086      1086          1086     1086         1086
# pt           1118  1118      1118          1118     1118         1118
# ru           1155  1155      1155          1155     1155         1155
# zh           1059  1059      1059          1059     1059         1059
#
#           CC Exp Date  CC Security Code  CC Provider  Email   Job  IP Address  \
# Language
# de               1155              1155         1155   1155  1155        1155
# el               1137              1137         1137   1137  1137        1137
# ...

# %% [markdown]
# Question No 6 - How many people have their job title is lawyer?

# %%
#Answer -------

df[df["Job"]=="Lawyer"].count()
# Out:
# Address             30
# Lot                 30
# AM or PM            30
# Browser Info        30
# Company             30
# Credit Card         30
# CC Exp Date         30
# CC Security Code    30
# CC Provider         30
# Email               30
# Job                 30
# IP Address          30
# Language            30
# Purchase Price      30
# dtype: int64

# %% [markdown]
# Question no 7- How many people made puchase during AM and how many during PM?

# %%
#Answer - There is one function called 
# value_counts()   --- It is used to count the occurance of each category

df["AM or PM"].value_counts()
# Out:
# PM    5068
# AM    4932
# Name: AM or PM, dtype: int64
